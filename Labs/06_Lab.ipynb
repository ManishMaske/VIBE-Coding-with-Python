# %% [markdown]
# **1. Track laps to miles**

# %% [markdown]
# One lap around a standard high-school running track is exactly 0.25 miles. Define a function named laps_to_miles that takes a number of laps as a parameter, and returns the number of miles. Then, write a main program that takes a number of laps as an input, calls function laps_to_miles() to calculate the number of miles, and outputs the number of miles.
#
# Output each floating-point value with two digits after the decimal point, which can be achieved as follows:
# print(f'{your_value:.2f}')
#
# Ex: If the input is:
#
# 7.6
# the output is:
#
# 1.90
# Ex: If the input is:
#
# 2.2
# the output is:
#
# 0.55
# The program must define and call the following function:
# def laps_to_miles(user_laps)
#
# Paste the following line of code in editor window.

# %%
 # Define your function here

if __name__ == '__main__':
    # Type your code here. Your code must call the function.

# %% [markdown]
# **Hint 1**

# %%
Compare output (1 point)
When input is
7.6
Standard output exactly matches
1.90

Compare output (1 point)
When input is
2.2
Standard output exactly matches
0.55

# %% [markdown]
# **Hint 2**

# %%
Unit test (3 points)
laps_to_miles(7.6)
Import student module you would like to test.
For example:
from main import add
from main import laps_to_miles

def test_passed(test_feedback):
# Write your test here. Return True if the test passes, and False otherwise.

# Optionally use the `write` method of the input parameter `testFeedback` to provide feedback to the student.

# For example:
#
# student_result = add(4, 2)
# if student_result == 6:
#    return True
# else:
#    test_feedback.write("add(4, 2) incorrectly returned " + str(student_result))
#    return False
student_result = laps_to_miles(7.6)

# Ensure correct return type
if (student_result is None):
    test_feedback.write("laps_to_miles(7.6) did not return a value.\n Your function may be missing a return statement.")
    return False

diff_amount = student_result - 1.90

if (diff_amount < 0):
    diff_amount = -diff_amount

if (diff_amount < 0.001):
    test_feedback.write("laps_to_miles(7.6) correctly returned " + str(student_result))
    return True

else:
    test_feedback.write("laps_to_miles(7.6) incorrectly returned " + str(student_result))
    return False

# %% [markdown]
# **Hint 3**

# %%
Remaining
Unit test (3 points)
laps_to_miles(2.2)
Import student module you would like to test.
For example:
from main import add
from main import laps_to_miles

def test_passed(test_feedback):
# Write your test here. Return True if the test passes, and False otherwise.

# Optionally use the `write` method of the input parameter `testFeedback` to provide feedback to the student.

# For example:
#
# student_result = add(4, 2)
# if student_result == 6:
#    return True
# else:
#    test_feedback.write("add(4, 2) incorrectly returned " + str(student_result))
#    return False
student_result = laps_to_miles(2.2)
# Ensure correct return type
if (student_result is None):
    test_feedback.write("laps_to_miles(2.2) did not return a value.\nYour function may be missing a return statement.")
    return False

diff_amount = student_result - 0.55

if (diff_amount < 0):
    diff_amount = -diff_amount

if (diff_amount < 0.001):
    test_feedback.write("laps_to_miles(2.2) correctly returned " + str(student_result))
    return True

else:
    test_feedback.write("laps_to_miles(2.2) incorrectly returned " + str(student_result))
    return False
5. Unit test (2 points)
laps_to_miles(104)

Import student module you would like to test.
For example:
from main import add
from main import laps_to_miles

def test_passed(test_feedback):
# Write your test here. Return True if the test passes, and False otherwise.

# Optionally use the `write` method of the input parameter `testFeedback` to provide feedback to the student.

# For example:
#
# student_result = add(4, 2)
# if student_result == 6:
#    return True
# else:
#    test_feedback.write("add(4, 2) incorrectly returned " + str(student_result))
#    return False
student_result = laps_to_miles(104)
# Ensure correct return type
if (student_result is None):
    test_feedback.write("laps_to_miles(104) did not return a value.\nYour function may be missing a return statement.")
    return False

diff_amount = student_result - 26

if (diff_amount < 0):
    diff_amount = -diff_amount

if (diff_amount < 0.001):
    test_feedback.write("laps_to_miles(104) correctly returned " + str(student_result) + "\n(26 miles is the length of a standard marathon race.)")
    return True

else:
    test_feedback.write("laps_to_miles(104) incorrectly returned " + str(student_result))
    return False

# %% [markdown]
# **2.Max magnitude**

# %% [markdown]
# Write a function max_magnitude() with three integer parameters that returns the largest magnitude value. Use the function in the main program that takes three integer inputs and outputs the largest magnitude value.
#
# Ex: If the inputs are:
#
# 5
# 7
# 9
# function max_magnitude() returns and the main program outputs:
#
# 9
# Ex: If the inputs are:
#
# -17
# -8
# -2
# function max_magnitude() returns and the main program outputs:
#
# -17
# Note: The function does not just return the largest value, which for -17 -8 -2 would be -2. Though not necessary, you may use the built-in absolute value function to determine the max magnitude, but you must still output the input number (Ex: Output -17, not 17).
#
# Your program must define and call the following function:
# def max_magnitude(user_val1, user_val2, user_val3)
#
# Paste the following code in editor window

# %%
# Define your function here.

if __name__ == '__main__':
    # Type your code here.

# %% [markdown]
# **Hint 1**

# %%
Compare output (1 point)
When input is
5
7
9
Standard output exactly matches
9

# %% [markdown]
# **Hint 2**

# %%
Compare output (1 point)
When input is
-17
-8
-2
Standard output exactly matches
-17

# %% [markdown]
# **Hint 3**

# %%
Compare output (1 point)
When input is
25
0
-50
Standard output exactly matches
-50

# %% [markdown]
# **3. Driving costs - functions**

# %% [markdown]
# Write a function driving_cost() with input parameters miles_per_gallon, dollars_per_gallon, and miles_driven, that returns the dollar cost to drive those miles. All items are of type float. The function called with arguments (20.0, 3.1599, 50.0) returns 7.89975.
#
# Define that function in a program whose inputs are the car's miles per gallon and the price of gas in dollars per gallon (both float). Output the gas cost for 10 miles, 50 miles, and 400 miles, by calling your driving_cost() function three times.
#
# Output each floating-point value with two digits after the decimal point, which can be achieved as follows:
# print(f'{your_value:.2f}')
#
# Ex: If the input is:
#
# 20.0
# 3.1599
# the output is:
#
# 1.58
# 7.90
# 63.20
# Your program must define and call a function:
# def driving_cost(miles_per_gallon, dollars_per_gallon, miles_driven)
#
# Paste the following line of code in editor

# %%
 # Define your function here.

if __name__ == '__main__':
    # Type your code here.

# %% [markdown]
# **Hint 1**

# %%
Compare output (2 points)
When input is
20.0
3.1599
Standard output exactly matches
1.58
7.90
63.20

# %% [markdown]
# **Hint 2**

# %%
Compare output (2 points)
When input is
30.0
3.8999
Standard output exactly matches
1.30
6.50
52.00

# %% [markdown]
# **4. Step counter**

# %% [markdown]
# A pedometer treats walking 1 step as walking 2.5 feet. Define a function named feet_to_steps that takes a float as a parameter, representing the number of feet walked, and returns an integer that represents the number of steps walked. Then, write a main program that reads the number of feet walked as an input, calls function feet_to_steps() with the input as an argument, and outputs the number of steps.
#
# Use floating-point arithmetic to perform the conversion.
#
# Ex: If the input is:
#
# 150.5
# the output is:
#
# 60
# The program must define and call the following function:
# def feet_to_steps(user_feet)
#
# Paste the following line of code in editor

# %%
# Define your function here

if __name__ == '__main__':
    # Type your code here.

# %% [markdown]
# **Hint 1**

# %%
Compare output (2 points)
When input is
150.5
Standard output exactly matches
60

# %% [markdown]
# **Hint 2**

# %%
Compare output (2 points)
When input is
10000
Standard output exactly matches
4000

# %% [markdown]
# **Hint 3**

# %%
Remaining Hints
3.Compare output (3 points)
When input is
11
Standard output exactly matches
4
4.Compare output (3 points)
When input is
79.25
Standard output exactly matches
31

# %% [markdown]
# **5. A jiffy**

# %% [markdown]
# A "jiffy" is the scientific name for 1/100th of a second. Define a function named jiffies_to_seconds that takes the number of "jiffies" as a parameter, and returns the number of seconds. Then, write a main program that reads the number of jiffies (float) as an input, calls function jiffies_to_seconds() with the input as argument, and outputs the number of seconds.
#
# Output each floating-point value with three digits after the decimal point, which can be achieved as follows:
# print(f'{your_value:.3f}')
#
# Ex: If the input is:
#
# 15.25
# the output is:
#
# 0.152
# The program must define and call the following function:
# def jiffies_to_seconds(user_jiffies)
#
# Paste the following code into editor.

# %%
# Define your function here

if __name__ == '__main__':
    # Type your code here. Your code must call the function.

# %% [markdown]
# **Hint 1**

# %%
Compare output (2 points)
When input is
15.25
Standard output exactly matches
0.152

# %% [markdown]
# **Hint 2**

# %%
Compare output (2 points)
When input is
250
Standard output exactly matches
2.5

# %% [markdown]
# **Hint3**

# %%
Compare output (2 points)
When input is
0.7
Standard output exactly matches
0.007

# %% [markdown]
# **6. Leap year - functions**

# %% [markdown]
# A common year in the modern Gregorian Calendar consists of 365 days. In reality, Earth takes longer to rotate around the sun. To account for the difference in time, every 4 years, a leap year takes place. A leap year is when a year has 366 days: An extra day, February 29th. The requirements for a given year to be a leap year are:
#
# The year must be divisible by 4
#
# If the year is a century year (1700, 1800, etc.), the year must be evenly divisible by 400
#
# Some example leap years are 1600, 1712, and 2016.
#
# Write a program that takes in a year and determines the number of days in February for that year.
#
# Ex: If the input is:
#
# 1712
# the output is:
#
# 1712 has 29 days in February.
# Ex: If the input is:
#
# 1913
# the output is:
#
# 1913 has 28 days in February.
# Your program must define and call the following function. The function should return the number of days in February for the input year.
# def days_in_feb(user_year)
#
# Paste the following line of code in editor window.

# %%
# Define your function here.

if __name__ == '__main__':
    # Type your code here. Your code must call the function.

# %% [markdown]
# **Hint 1**

# %%
Compare output (2 points)
When input is
1712
Standard output exactly matches
1712 has 29 days in February.

Compare output (2 points)
When input is
1913
Standard output exactly matches
1913 has 28 days in February.

# %% [markdown]
# **Hint 2**

# %%
3.Compare output (2 points)
When input is
1600
Standard output exactly matches
1600 has 29 days in February.

# %% [markdown]
# **Hint 3**

# %%
Remaining Hints:
4.Compare output (2 points)
When input is
1600
Standard output exactly matches
1600 has 29 days in February.

# %% [markdown]
# **7. Convert to binary - functions**

# %% [markdown]
# Write a program that takes in a positive integer as input, and outputs a string of 1's and 0's representing the integer in binary. For an integer x, the algorithm is:
#
# As long as x is greater than 0
# Output x % 2 (remainder is either 0 or 1)
# x = x // 2
# Note: The above algorithm outputs the 0's and 1's in reverse order. You will need to write a second function to reverse the string.
#
# Ex: If the input is:
#
# 6
# the output is:
#
# 110
# The program must define and call the following two functions. Define a function named int_to_reverse_binary() that takes an integer as a parameter and returns a string of 1's and 0's representing the integer in binary (in reverse). Define a function named string_reverse() that takes an input string as a parameter and returns a string representing the input string in reverse.
# def int_to_reverse_binary(integer_value)
# def string_reverse(input_string)
#
# Paste the follwoing line of code in editor window.

# %%
# Define your functions here.

if __name__ == '__main__':
    # Type your code here.
    # Your code must call int_to_reverse_binary() to get
    # the binary string of an integer in a reverse order.
    # Then call string_reverse() to reverse the string
    # returned from int_to_reverse_binary().

# %% [markdown]
# **Hint 1**

# %%
Compare output (2 points)
When input is
6
Standard output exactly matches
110

# %% [markdown]
# **Hint 2**

# %%
Compare output (2 points)
When input is
19
Standard output exactly matches
10011

# %% [markdown]
# **8.Swapping variables**

# %% [markdown]
# Define a function named swap_values that takes four integers as parameters and swaps the first with the second, and the third with the fourth values. Then write a main program that reads four integers from input, calls function swap_values() to swap the values, and prints the swapped values on a single line separated with spaces.
#
# Ex: If the input is:
#
# 3
# 8
# 2
# 4
# function swap_values() returns and the main program outputs:
#
# 8 3 4 2
# The program must define and call the following function.
# def swap_values(user_val1, user_val2, user_val3, user_val4)
#
# Paste the follwoing line of code in editor window.

# %%
# Define your function here.

if __name__ == '__main__':
    # Type your code here. Your code must call the function.

# %% [markdown]
# **Hint 1**

# %%
Compare output (2 points)
When input is
3
4
5
6
Standard output exactly matches
4 3 6 5

# %% [markdown]
# **Hint 2**

# %%
Compare output (2 points)
When input is
-1
10
4
-6
Standard output exactly matches
10 -1 -6 4

# %% [markdown]
# **Hint 3**

# %%
Compare output (2 points)
When input is
9
0
13
-5
Standard output exactly matches
0 9 -5 13

Compare output (2 points)
When input is
11
11
11
11
Standard output exactly matches
11 11 11 11

# %% [markdown]
# **9. Exact change - functions**

# %% [markdown]
# Define a function called exact_change that takes the total change amount in cents and calculates the change using the fewest coins. The coin types are pennies, nickels, dimes, and quarters. Then write a main program that reads the total change amount as an integer input, calls exact_change(), and outputs the change, one coin type per line. Use singular and plural coin names as appropriate, like 1 penny vs. 2 pennies. Output "no change" if the input is 0 or less.
#
# Ex: If the input is:
#
# 0
# (or less), the output is:
#
# no change
# Ex: If the input is:
#
# 45
# the output is:
#
# 2 dimes
# 1 quarter
# Your program must define and call the following function. The function exact_change() should return num_pennies, num_nickels, num_dimes, and num_quarters.
# def exact_change(user_total)
#
# Paste the following line of code in editor.

# %%
# Define your function here

if __name__ == '__main__':
    input_val = int(input())
    num_pennies, num_nickels, num_dimes, num_quarters = exact_change(input_val)

    # Type your code here.

# %% [markdown]
# **Hint 1**

# %%
Compare output (1 point)
When input is
45
Standard output exactly matches
2 dimes
1 quarter

Compare output (1 point)
When input is
0
Standard output exactly matches
no change

Compare output (2 points)
When input is
156
Standard output exactly matches
1 penny
1 nickel
6 quarters

# %% [markdown]
# **Hint 2**

# %%
Unit test (3 points)
exact_change(300). Should return 0, 0, 0, 12

# %% [markdown]
# **Hint 3**

# %%
Unit test (3 points)
exact_change(141). Should return 1, 1, 1, 5

# %% [markdown]
# **10. Multiples of ten in a list**

# %% [markdown]
# Write a program that reads a list of integers, and outputs whether the list contains all multiples of 10, no multiples of 10, or mixed values. Define a function named is_list_mult10 that takes a list as a parameter, and returns a boolean that represents whether the list contains all multiples of ten. Define a function named is_list_no_mult10 that takes a list as a parameter and returns a boolean that represents whether the list contains no multiples of ten.
#
# Then, write a main program that takes an integer, representing the size of the list, followed by the list values. The first integer is not in the list.
#
# Ex: If the input is:
#
# 5
# 20
# 40
# 60
# 80
# 100
# the output is:
# all multiples of 10
#
# Ex: If the input is:
#
# 5
# 11
# -32
# 53
# -74
# 95
#
# the output is:
# no multiples of 10
#
# Ex: If the input is:
#
# 5
# 10
# 25
# 30
# 40
# 55
#
# the output is:
# mixed values
#
# The program must define and call the following two functions. is_list_mult10() returns true if all integers in the list are multiples of 10 and false otherwise. is_list_no_mult10() returns true if no integers in the list are multiples of 10 and false otherwise.
# def is_list_mult10(my_list)
# def is_list_no_mult10(my_list)
#
# Paste the following line of code in editor window.

# %%
# Define your functions here

if __name__ == '__main__':
    # Type your code here.

# %% [markdown]
# **Hint 1**

# %%
Compare output
When input is
5
20
40
60
80
100

Standard output exactly matches
all multiples of 10

# %% [markdown]
# **Hint 2**

# %%
Compare output
When input is
5
11
-32
53
-74
95

Standard output exactly matches
no multiples of 10

# %% [markdown]
# **Hint 3**

# %%
Compare output
When input is
5
10
25
30
40
55

Standard output exactly matches
mixed values

# %% [markdown]
# **11. Output values in a list below a user defined amount - functions**

# %% [markdown]
# Write a program that first gets a list of integers from input. The input begins with an integer indicating the number of integers that follows. Then, get the last value from the input, and output all integers less than or equal to that value.
#
# Ex: If the input is:
#
# 5
# 50
# 60
# 140
# 200
# 75
# 100
# the output is:
#
# 50
# 60
# 75
# The 5 indicates that five integers are in the list, namely 50, 60, 140, 200, and 75. The 100 indicates that the program should output all integers less than or equal to 100, so the program outputs 50, 60, and 75.
#
# Such functionality is common on sites like Amazon, where a user can filter results. Utilizing functions will help to make your main very clean and intuitive.
#
# The program must define the following two functions:
# def get_user_values() - read from input the size of the list, the integers in the list, and the threshold value. Return the list of integers and the threshold value.
#
# def ints_less_than_or_equal_to_threshold(user_values, upper_threshold) - create a new list that contains values in user_values that are less than or equal to upper_threshold. Return the newly created list.
#
# Paste the following line of code in editor.

# %%
# Define your functions here

if __name__ == '__main__':
    user_values, upper_threshold = get_user_values()
    res_values = ints_less_than_or_equal_to_threshold(user_values, upper_threshold)

    for value in res_values:
        print(value)

# %% [markdown]
# **Hint 1**

# %%
Compare output (2 points)
When input is
5
50
60
140
200
75
100

Standard output exactly matches
50
60
75

# %% [markdown]
# **Hint 2**

# %%
Compare output (2 points)
When input is
5
50
60
140
200
75
70

Standard output exactly matches
50
60

# %% [markdown]
# **Hint 3**

# %%
Compare output (2 points)
When input is
7
25
32
27
28
27
25
31
28

Standard output exactly matches
25
27
28
27
25

# %% [markdown]
# **12 Warm up: Text analyzer & modifier**

# %% [markdown]
# (1) Prompt the user to enter a string of their choosing. Output the string. (1 pt)
#
# Ex:
#
# Enter a sentence or phrase:
# The only thing we have to fear is fear itself.
#
# You entered: The only thing we have to fear is fear itself.
# (2) Complete the get_num_of_characters() function, which returns the number of characters in the user's string. We encourage you to use a for loop in this function. (2 pts)
#
# (3) Extend the program by calling the get_num_of_characters() function and then output the returned result. (1 pt)
#
# (4) Extend the program further by implementing the output_without_whitespace() function. output_without_whitespace() outputs the string's characters except for whitespace (spaces, tabs). Note: A tab is '\t'. Call the output_without_whitespace() function in main(). (2 pts)
#
# Ex:
#
# Enter a sentence or phrase:
# The only thing we have to fear is fear itself.
#
# You entered: The only thing we have to fear is fear itself.
#
# Number of characters: 46
# String with no whitespace: Theonlythingwehavetofearisfearitself.
#
# Paste the following line of code in editor.

# %%
def get_num_of_characters(input_str):
    # Type your code here
    return


if __name__ == '__main__':
    # Type your code here

# %% [markdown]
# **Hint 1**

# %%
Compare output (1 point)
When input is
The only thing we have to fear is fear itself.
Standard output starts with
Enter a sentence or phrase:
You entered: The only thing we have to fear is fear itself.

Unit test (1 point)
Tests that get_num_of_characters() returns 46 for "The only thing we have to fear is fear itself."

# %% [markdown]
# **Hint 2**

# %%
Unit test (1 point)
Tests that get_num_of_characters() returns 44 for "The rain in Spain stays mainly in the plain."

Compare output (1 point)
When input is
The only thing we have to fear is fear itself.
Standard output starts with
Enter a sentence or phrase:

You entered: The only thing we have to fear is fear itself.

Number of characters: 46

# %% [markdown]
# **Hint 3**

# %%
Compare output (1 point)
When input is
The only thing we have to fear is fear itself.
Standard output exactly matches
Enter a sentence or phrase:
You entered: The only thing we have to fear is fear itself.

Number of characters: 46
String with no whitespace: Theonlythingwehavetofearisfearitself.
6. Compare output (1 point)
When input is
The rain in Spain stays mainly in the plain.
Standard output exactly matches
Enter a sentence or phrase:

You entered: The rain in Spain stays mainly in the plain.

Number of characters: 44
String with no whitespace: TheraininSpainstaysmainlyintheplain.
